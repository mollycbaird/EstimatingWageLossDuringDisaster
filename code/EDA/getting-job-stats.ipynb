# %% [markdown]
# # all data found from
# https://www.bls.gov/oes/tables.htm

# %%
import pandas as pd

# %%
def null_cleaning(df):
    null_cols = []
    problem_cols = []
    
    # looping through the columns
    for i in range(df.shape[1]):
        # counting the number of null vals in the column
        num_nulls = df.isnull().sum()[i]
        # if there are more than 0 null values, add the column to our list, and see what % of the data it is
        if num_nulls != 0:
            col_name = df.columns[i]
            percent_of_data = round(num_nulls/df.shape[0], 3)
            null_cols.append([col_name, num_nulls, percent_of_data])
            # if this column is over 20% nulls, then mark it as a problem column
            if percent_of_data >= 0.2:
                problem_cols.append(col_name)
                
    # what happens if we drop the problem columns?
    df_no_prob_cols = df.drop(columns = problem_cols)
    prob_cols_percent = df_no_prob_cols.shape[1] / df.shape[1]
    
    #what happens is we drop the problem rows too?
    df_no_nulls = df_no_prob_cols.dropna()
    prob_rows_percent = df_no_nulls.shape[0]/df_no_prob_cols.shape[0]
    
    print("The problem columns are: ", problem_cols)
    print("After dropping the problem columns, you are left with ", prob_cols_percent, "% of your columns.")
    print("After dropping the problem columns, and then dropping all rows containing nulls,\n you are left with ", 
          prob_rows_percent, "% of your rows.")
    return null_cols

# %% [markdown]
# # 1997

# %%
df_97 = pd.read_excel('../data/state_1997_dl.xls')

# %%
df_97.shape
# Out:
# (34473, 23)

# %%
df_97.head(47)
# Out:
#    Unnamed: 0                           1997 State OES Estimates Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN    Occupational Employment Statistics (OES) Survey        NaN
# 2         NaN    Bureau of Labor Statistics, Department of Labor        NaN
# 3         NaN              website:    http://stats.bls.gov/oes/        NaN
# 4         NaN                           phone:      202-691-6569        NaN
# 5         NaN                                                NaN        NaN
# 6         NaN                                     Column labels:        NaN
# 7         NaN                      area - fips code of the state        NaN
# 8         NaN                        st - the state abbreviation        NaN
# 9         NaN                             state - the state name        NaN
# 10        NaN  occ_code - a unique, five-digit numerical iden...        NaN
# 11        NaN  occ_title - a descriptive title that correspon...        NaN
# 12        NaN           group - indicates major groups ("major")        NaN
# 13        NaN  tot_emp - the estimated total occupational emp...        NaN
# 14        NaN  emp_prse - the percent relative standard error...        NaN
# 15        NaN  h_mean - mean hourly wage, the estimated total...        NaN
# 16        NaN  a_mean - mean annual wage, the estimated mean ...        NaN
# 17        NaN  mean_prse - the percent relative standard erro...        NaN
# 18        NaN  h_wpct10 - the 10% percentile hourly wage (10%...        NaN
# 19        NaN          h_wpct25 - the 25% percentile hourly wage        NaN
# 20        NaN  h_median - the median (50% percentile) hourly ...        NaN
# 21        NaN          h_wpct75 - the 75% percentile hourly wage        NaN
# 22        NaN          h_wpct90 - the 90% percentile hourly wage        NaN
# 23        NaN  a_wpct10 - the 10% percentile annual wage (10%...        NaN
# 24        NaN          a_wpct25 - the 25% percentile annual wage        NaN
# 25        NaN  a_median - the median (50% percentile) annual ...        NaN
# 26        NaN          a_wpct75 - the 75% percentile annual wage        NaN
# 27        NaN          a_wpct90 - the 90% percentile annual wage        NaN
# 28        NaN  annual - "true" identifies occupations for whi...        NaN
# 29        NaN  release - "no" indicates that no wage or emplo...        NaN
# 30        NaN  year - year the data were collected; some of t...        NaN
# 31        NaN                                                NaN        NaN
# 32        NaN                                             Notes:        NaN
# 33        NaN  * = indicates that a wage estimate is not avai...        NaN
# 34        NaN  ** = indicates that an employment estimate is ...        NaN
# 35        NaN  *** = The wage data for two occupations, airli...        NaN
# 36        NaN  # = indicates a median wage greater than $60.0...        NaN
# 37        NaN  Relative Standard Error (RSE) is a measure of ...        NaN
# 38        NaN                                                NaN        NaN
# 39       area                                                 st      state
# 40         01                                                 AL    Alabama
# 41         01                                                 AL    Alabama
# 42         01                                                 AL    Alabama
# 43         01                                                 AL    Alabama
# 44         01                                                 AL    Alabama
# 45         01                                                 AL    Alabama
# 46         01                                                 AL    Alabama
#
#    Unnamed: 3                                         Unnamed: 4 Unnamed: 5  \
# 0         NaN                                                NaN        NaN
# 1         NaN                                                NaN        NaN
# 2         NaN                                                NaN        NaN
# 3         NaN                                                NaN        NaN
# 4         NaN                                                NaN        NaN
# 5         NaN                                                NaN        NaN
# 6         NaN                                                NaN        NaN
# 7         NaN                                                NaN        NaN
# 8         NaN                                                NaN        NaN
# 9         NaN                                                NaN        NaN
# 10        NaN                                                NaN        NaN
# 11        NaN                                                NaN        NaN
# 12        NaN                                                NaN        NaN
# 13        NaN                                                NaN        NaN
# 14        NaN                                                NaN        NaN
# 15        NaN                                                NaN        NaN
# 16        NaN                                                NaN        NaN
# 17        NaN                                                NaN        NaN
# 18        NaN                                                NaN        NaN
# 19        NaN                                                NaN        NaN
# 20        NaN                                                NaN        NaN
# 21        NaN                                                NaN        NaN
# 22        NaN                                                NaN        NaN
# 23        NaN                                                NaN        NaN
# 24        NaN                                                NaN        NaN
# 25        NaN                                                NaN        NaN
# 26        NaN                                                NaN        NaN
# 27        NaN                                                NaN        NaN
# 28        NaN                                                NaN        NaN
# 29        NaN                                                NaN        NaN
# 30        NaN                                                NaN        NaN
# 31        NaN                                                NaN        NaN
# 32        NaN                                                NaN        NaN
# 33        NaN                                                NaN        NaN
# 34        NaN                                                NaN        NaN
# 35        NaN                                                NaN        NaN
# 36        NaN                                                NaN        NaN
# 37        NaN                                                NaN        NaN
# 38        NaN                                                NaN        NaN
# 39   occ_code                                           occ_titl      group
# 40      10000          Managerial and Administrative Occupations        div
# 41      13000  Staff and Administrative Specialty Managerial ...        maj
# 42      13002                                 Financial Managers        NaN
# 43      13005  Personnel, Training, and Labor Relations Managers        NaN
# 44      13008                                Purchasing Managers        NaN
# 45      13011  Marketing, Advertising, and Public Relations M...        NaN
# 46      13014                   Administrative Services Managers        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 5         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 6         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 7         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 8         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 9         NaN        NaN        NaN        NaN  ...         NaN         NaN
# 10        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 11        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 12        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 13        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 14        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 15        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 16        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 17        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 18        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 19        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 20        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 21        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 22        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 23        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 24        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 25        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 26        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 27        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 28        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 29        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 30        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 31        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 32        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 33        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 34        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 35        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 36        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 37        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 38        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 39    tot_emp   emp_prse     h_mean     a_mean  ...    h_median    h_wpct75
# 40        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 41         **         **      18.04      37530  ...       16.25       22.07
# 42       8140        3.3      24.23      50400  ...       20.97       33.97
# 43       2760        2.9      20.84      43350  ...       19.29       28.17
# 44       2370        4.7      19.07      39660  ...       15.99       23.59
# 45       4500        5.2      23.76      49420  ...       21.52       33.50
# 46       2950        4.5      20.98      43650  ...       19.32       27.53
#
#    Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN         NaN         NaN
# 39    h_wpct90    a_wpct10    a_wpct25    a_median    a_wpct75    a_wpct90
# 40         NaN         NaN         NaN         NaN         NaN         NaN
# 41       32.97       20758       25875       33800       45906       68578
# 42       46.32       24336       32261     43617.6       70658       96346
# 43       38.99       21840       28018     40123.2       58594       81099
# 44       39.15       17451       23442     33259.2       49067       81432
# 45       43.35       23358       30950     44761.6       69680       90168
# 46       38.76       23462       30160     40185.6       57262       80621
#
#    Unnamed: 21 Unnamed: 22
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN
# 28         NaN         NaN
# 29         NaN         NaN
# 30         NaN         NaN
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN         NaN
# 34         NaN         NaN
# 35         NaN         NaN
# 36         NaN         NaN
# 37         NaN         NaN
# 38         NaN         NaN
# 39      annual        year
# 40         NaN         NaN
# 41         NaN        1997
# 42         NaN        1997
# 43         NaN        1997
# 44         NaN        1997
# 45         NaN        1997
# 46         NaN        1997
#
# [47 rows x 23 columns]

# %%
# dropping indicies 0 through 38

df_97.drop(index = list(range(39)), inplace = True)

# %%
df_97.head()
# Out:
#    Unnamed: 0 1997 State OES Estimates Unnamed: 2 Unnamed: 3  \
# 39       area                       st      state   occ_code
# 40         01                       AL    Alabama      10000
# 41         01                       AL    Alabama      13000
# 42         01                       AL    Alabama      13002
# 43         01                       AL    Alabama      13005
#
#                                            Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 39                                           occ_titl      group    tot_emp
# 40          Managerial and Administrative Occupations        div        NaN
# 41  Staff and Administrative Specialty Managerial ...        maj         **
# 42                                 Financial Managers        NaN       8140
# 43  Personnel, Training, and Labor Relations Managers        NaN       2760
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 39   emp_prse     h_mean     a_mean  ...    h_median    h_wpct75    h_wpct90
# 40        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 41         **      18.04      37530  ...       16.25       22.07       32.97
# 42        3.3      24.23      50400  ...       20.97       33.97       46.32
# 43        2.9      20.84      43350  ...       19.29       28.17       38.99
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 39    a_wpct10    a_wpct25    a_median    a_wpct75    a_wpct90      annual
# 40         NaN         NaN         NaN         NaN         NaN         NaN
# 41       20758       25875       33800       45906       68578         NaN
# 42       24336       32261     43617.6       70658       96346         NaN
# 43       21840       28018     40123.2       58594       81099         NaN
#
#    Unnamed: 22
# 39        year
# 40         NaN
# 41        1997
# 42        1997
# 43        1997
#
# [5 rows x 23 columns]

# %%
new_header = df_97.iloc[0] #grab the first row for the header
df_97 = df_97[1:].copy() #take the data less the header row
df_97.columns = new_header #set the header row as the df header

# %%
df_97.head()
# Out:
# 39 area  st    state occ_code  \
# 40   01  AL  Alabama    10000
# 41   01  AL  Alabama    13000
# 42   01  AL  Alabama    13002
# 43   01  AL  Alabama    13005
# 44   01  AL  Alabama    13008
#
# 39                                           occ_titl group tot_emp emp_prse  \
# 40          Managerial and Administrative Occupations   div     NaN      NaN
# 41  Staff and Administrative Specialty Managerial ...   maj      **       **
# 42                                 Financial Managers   NaN    8140      3.3
# 43  Personnel, Training, and Labor Relations Managers   NaN    2760      2.9
# 44                                Purchasing Managers   NaN    2370      4.7
#
# 39 h_mean a_mean  ... h_median h_wpct75 h_wpct90 a_wpct10 a_wpct25 a_median  \
# 40    NaN    NaN  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 41  18.04  37530  ...    16.25    22.07    32.97    20758    25875    33800
# 42  24.23  50400  ...    20.97    33.97    46.32    24336    32261  43617.6
# 43  20.84  43350  ...    19.29    28.17    38.99    21840    28018  40123.2
# 44  19.07  39660  ...    15.99    23.59    39.15    17451    23442  33259.2
#
# 39 a_wpct75 a_wpct90 annual  year
# 40      NaN      NaN    NaN   NaN
# 41    45906    68578    NaN  1997
# 42    70658    96346    NaN  1997
# 43    58594    81099    NaN  1997
# 44    49067    81432    NaN  1997
#
# [5 rows x 23 columns]

# %%
df_97.isna().sum().sum()
# Out:
# 70574

# %%
null_cleaning(df_97)
# Out:
# The problem columns are:  ['group', 'annual']
# After dropping the problem columns, you are left with  0.9130434782608695 % of your columns.
# After dropping the problem columns, and then dropping all rows containing nulls,
#  you are left with  0.9890221589754015 % of your rows.
# [['group', 31764, 0.922],
#  ['tot_emp', 378, 0.011],
#  ['emp_prse', 378, 0.011],
#  ['h_mean', 378, 0.011],
#  ['a_mean', 378, 0.011],
#  ['mean_prse', 378, 0.011],
#  ['h_wpct10', 378, 0.011],
#  ['h_wpct25', 378, 0.011],
#  ['h_median', 378, 0.011],
#  ['h_wpct75', 378, 0.011],
#  ['h_wpct90', 378, 0.011],
#  ['a_wpct10', 378, 0.011],
#  ['a_wpct25', 378, 0.011],
#  ['a_median', 378, 0.011],
#  ['a_wpct75', 378, 0.011],
#  ['a_wpct90', 378, 0.011],
#  ['annual', 32762, 0.951],
#  ['year', 378, 0.011]]

# %%
features = ['st','occ_code','occ_titl','tot_emp','h_mean','a_mean','year']
df_97 = df_97[features].copy()

# %%
df_97.head()
# Out:
# 39  st occ_code                                           occ_titl tot_emp  \
# 40  AL    10000          Managerial and Administrative Occupations     NaN
# 41  AL    13000  Staff and Administrative Specialty Managerial ...      **
# 42  AL    13002                                 Financial Managers    8140
# 43  AL    13005  Personnel, Training, and Labor Relations Managers    2760
# 44  AL    13008                                Purchasing Managers    2370
#
# 39 h_mean a_mean  year
# 40    NaN    NaN   NaN
# 41  18.04  37530  1997
# 42  24.23  50400  1997
# 43  20.84  43350  1997
# 44  19.07  39660  1997

# %%
null_cleaning(df_97)
# Out:
# The problem columns are:  []
# After dropping the problem columns, you are left with  1.0 % of your columns.
# After dropping the problem columns, and then dropping all rows containing nulls,
#  you are left with  0.9890221589754015 % of your rows.
# [['tot_emp', 378, 0.011],
#  ['h_mean', 378, 0.011],
#  ['a_mean', 378, 0.011],
#  ['year', 378, 0.011]]

# %%
df_97[df_97['tot_emp'].isnull()]['occ_titl'].value_counts()
# Out:
# Professional, Paraprofessional, and Technical Occupations                              54
# Managerial and Administrative Occupations                                              54
# Clerical and Administrative Support Occupations                                        54
# Agricultural, Forestry, Fishing, and Related Occupations                               54
# Sales and Related Occupations                                                          54
# Production, Construction, Operating, Maintenance, and Material Handling Occupations    54
# Service Occupations                                                                    54
# Name: occ_titl, dtype: int64

# %%
df_97.shape
# Out:
# (34433, 7)

# %%
df_97.dtypes
# Out:
# 39
# st          object
# occ_code    object
# occ_titl    object
# tot_emp     object
# h_mean      object
# a_mean      object
# year        object
# dtype: object

# %%
df_97.rename(columns = {'occ_titl':'occ_title'}, inplace = True)

# %%
df_97.head()
# Out:
# 39  st occ_code                                          occ_title tot_emp  \
# 40  AL    10000          Managerial and Administrative Occupations     NaN
# 41  AL    13000  Staff and Administrative Specialty Managerial ...      **
# 42  AL    13002                                 Financial Managers    8140
# 43  AL    13005  Personnel, Training, and Labor Relations Managers    2760
# 44  AL    13008                                Purchasing Managers    2370
#
# 39 h_mean a_mean  year
# 40    NaN    NaN   NaN
# 41  18.04  37530  1997
# 42  24.23  50400  1997
# 43  20.84  43350  1997
# 44  19.07  39660  1997

# %%
df_97.to_csv('./1997_jobs.csv')

# %% [markdown]
# # 1998

# %%
df_98 = pd.read_excel('../data/state_1998_dl.xls')

# %%
# dropping indicies 0 through 38

df_98.drop(index = list(range(39)), inplace = True)

# %%
df_98.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 39        NaN        NaN        NaN        NaN
# 40       area         st      state   occ_code
# 41         01         AL    Alabama      10000
# 42         01         AL    Alabama      13000
# 43         01         AL    Alabama      13002
#
#                                            Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 39                                                NaN        NaN        NaN
# 40                                          occ_title      group    tot_emp
# 41          Managerial and Administrative Occupations        div        NaN
# 42  Staff and Administrative Specialty Managerial ...        maj      38650
# 43                                 Financial Managers        NaN       8140
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 39        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 40   emp_prse     h_mean     a_mean  ...    h_median    h_wpct75    h_wpct90
# 41        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 42        1.8      18.71      38930  ...          17       22.98       34.74
# 43        2.5      24.43      50800  ...       21.51       34.28       46.16
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 39         NaN         NaN         NaN         NaN         NaN         NaN
# 40    a_wpct10    a_wpct25    a_median    a_wpct75    a_wpct90      annual
# 41         NaN         NaN         NaN         NaN         NaN         NaN
# 42       20530       26460       35350       47800       72260         NaN
# 43       23740       32070       44740       71300       96020         NaN
#
#    Unnamed: 22
# 39         NaN
# 40       year
# 41         NaN
# 42        1998
# 43        1998
#
# [5 rows x 23 columns]

# %%
new_header = df_98.iloc[0] #grab the first row for the header
df_98 = df_98[1:].copy() #take the data less the header row
df_98.columns = new_header #set the header row as the df header

# %%
df_98.head()
# Out:
# 39   NaN NaN      NaN       NaN  \
# 40  area  st    state  occ_code
# 41    01  AL  Alabama     10000
# 42    01  AL  Alabama     13000
# 43    01  AL  Alabama     13002
# 44    01  AL  Alabama     13005
#
# 39                                                NaN    NaN      NaN  \
# 40                                          occ_title  group  tot_emp
# 41          Managerial and Administrative Occupations    div      NaN
# 42  Staff and Administrative Specialty Managerial ...    maj    38650
# 43                                 Financial Managers    NaN     8140
# 44  Personnel, Training, and Labor Relations Managers    NaN     2910
#
# 39       NaN     NaN     NaN  ...       NaN       NaN       NaN       NaN  \
# 40  emp_prse  h_mean  a_mean  ...  h_median  h_wpct75  h_wpct90  a_wpct10
# 41       NaN     NaN     NaN  ...       NaN       NaN       NaN       NaN
# 42       1.8   18.71   38930  ...        17     22.98     34.74     20530
# 43       2.5   24.43   50800  ...     21.51     34.28     46.16     23740
# 44       2.4   21.53   44780  ...     19.79     30.27     40.04     21730
#
# 39       NaN       NaN       NaN       NaN     NaN    NaN
# 40  a_wpct25  a_median  a_wpct75  a_wpct90  annual  year
# 41       NaN       NaN       NaN       NaN     NaN    NaN
# 42     26460     35350     47800     72260     NaN   1998
# 43     32070     44740     71300     96020     NaN   1998
# 44     28430     41150     62970     83280     NaN   1998
#
# [5 rows x 23 columns]

# %%
new_header = df_98.iloc[0] #grab the first row for the header
df_98 = df_98[1:].copy() #take the data less the header row
df_98.columns = new_header #set the header row as the df header

# %%
df_98.head()
# Out:
# 40 area  st    state occ_code  \
# 41   01  AL  Alabama    10000
# 42   01  AL  Alabama    13000
# 43   01  AL  Alabama    13002
# 44   01  AL  Alabama    13005
# 45   01  AL  Alabama    13008
#
# 40                                          occ_title group tot_emp emp_prse  \
# 41          Managerial and Administrative Occupations   div     NaN      NaN
# 42  Staff and Administrative Specialty Managerial ...   maj   38650      1.8
# 43                                 Financial Managers   NaN    8140      2.5
# 44  Personnel, Training, and Labor Relations Managers   NaN    2910      2.4
# 45                                Purchasing Managers   NaN    2490      9.6
#
# 40 h_mean a_mean  ... h_median h_wpct75 h_wpct90 a_wpct10 a_wpct25 a_median  \
# 41    NaN    NaN  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 42  18.71  38930  ...       17    22.98    34.74    20530    26460    35350
# 43  24.43  50800  ...    21.51    34.28    46.16    23740    32070    44740
# 44  21.53  44780  ...    19.79    30.27    40.04    21730    28430    41150
# 45  18.06  37560  ...    15.75    22.77    37.06    15400    20810    32750
#
# 40 a_wpct75 a_wpct90 annual year
# 41      NaN      NaN    NaN   NaN
# 42    47800    72260    NaN  1998
# 43    71300    96020    NaN  1998
# 44    62970    83280    NaN  1998
# 45    47360    77090    NaN  1998
#
# [5 rows x 23 columns]

# %%
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean','year ']
df_98 = df_98[features].copy()

# %%
# fixing space at the end of year
df_98.rename(columns = {'year ':'year'}, inplace = True)

# %%
null_cleaning(df_98)
# Out:
# The problem columns are:  []
# After dropping the problem columns, you are left with  1.0 % of your columns.
# After dropping the problem columns, and then dropping all rows containing nulls,
#  you are left with  0.9894117647058823 % of your rows.
# [['tot_emp', 378, 0.011],
#  ['h_mean', 378, 0.011],
#  ['a_mean', 378, 0.011],
#  ['year', 378, 0.011]]

# %%
df_98[df_98['tot_emp'].isnull()]['occ_title'].value_counts()
# Out:
# Professional, Paraprofessional, and Technical Occupations                              54
# Managerial and Administrative Occupations                                              54
# Clerical and Administrative Support Occupations                                        54
# Agricultural, Forestry, Fishing, and Related Occupations                               54
# Sales and Related Occupations                                                          54
# Production, Construction, Operating, Maintenance, and Material Handling Occupations    54
# Service Occupations                                                                    54
# Name: occ_title, dtype: int64

# %%
df_98.dtypes
# Out:
# 40
# st           object
# occ_code     object
# occ_title    object
# tot_emp      object
# h_mean       object
# a_mean       object
# year         object
# dtype: object

# %% [markdown]
# # 1999

# %%
df_99 = pd.read_excel('../data/state_1999_dl.xls')

# %%
df_99.head(45)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN                                                NaN        NaN
# 2         NaN    Occupational Employment Statistics (OES) Survey        NaN
# 3         NaN    Bureau of Labor Statistics, Department of Labor        NaN
# 4         NaN              website:    http://stats.bls.gov/oes/        NaN
# 5         NaN                           phone:      202-691-6569        NaN
# 6         NaN                                                NaN        NaN
# 7         NaN                                     Column labels:        NaN
# 8         NaN                      area - fips code of the state        NaN
# 9         NaN                        st - the state abbreviation        NaN
# 10        NaN                             state - the state name        NaN
# 11        NaN  occ_code - a unique, six-digit numerical ident...        NaN
# 12        NaN  occ_title - a descriptive title that correspon...        NaN
# 13        NaN           group - indicates major groups ("major")        NaN
# 14        NaN  tot_emp - the estimated total occupational emp...        NaN
# 15        NaN  emp_prse - the percent relative standard error...        NaN
# 16        NaN  h_mean - mean hourly wage, the estimated total...        NaN
# 17        NaN  a_mean - mean annual wage, the estimated mean ...        NaN
# 18        NaN  mean_prse - the percent relative standard erro...        NaN
# 19        NaN  h_wpct10 - the 10% percentile hourly wage (10%...        NaN
# 20        NaN          h_wpct25 - the 25% percentile hourly wage        NaN
# 21        NaN  h_median - the median (50% percentile) hourly ...        NaN
# 22        NaN          h_wpct75 - the 75% percentile hourly wage        NaN
# 23        NaN          h_wpct90 - the 90% percentile hourly wage        NaN
# 24        NaN  a_wpct10 - the 10% percentile annual wage (10%...        NaN
# 25        NaN          a_wpct25 - the 25% percentile annual wage        NaN
# 26        NaN  a_median - the median (50% percentile) annual ...        NaN
# 27        NaN          a_wpct75 - the 75% percentile annual wage        NaN
# 28        NaN          a_wpct90 - the 90% percentile annual wage        NaN
# 29        NaN  one or three - indicates whether a wage estima...        NaN
# 30        NaN  annual - "true" identifies occupations for whi...        NaN
# 31        NaN  release - "no" indicates that no wage or emplo...        NaN
# 32        NaN  year - year the data were collected; some of t...        NaN
# 33        NaN                                                NaN        NaN
# 34        NaN                                             Notes:        NaN
# 35        NaN  * = indicates that a wage estimate is not avai...        NaN
# 36        NaN  ** = indicates that an employment estimate is ...        NaN
# 37        NaN  *** = The wage data for two occupations, airli...        NaN
# 38        NaN  # = indicates a wage greater than $70.00 per h...        NaN
# 39        NaN  Relative Standard Error (RSE) is a measure of ...        NaN
# 40        NaN  Estimates for residual, "All Other . . .," occ...        NaN
# 41        NaN                                                NaN        NaN
# 42       area                                                 st      state
# 43         01                                                 AL    Alabama
# 44         01                                                 AL    Alabama
#
#    Unnamed: 3                 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0         NaN  1999 State OES Estimates         NaN        NaN        NaN
# 1         NaN                        NaN        NaN        NaN        NaN
# 2         NaN                        NaN        NaN        NaN        NaN
# 3         NaN                        NaN        NaN        NaN        NaN
# 4         NaN                        NaN        NaN        NaN        NaN
# 5         NaN                        NaN        NaN        NaN        NaN
# 6         NaN                        NaN        NaN        NaN        NaN
# 7         NaN                        NaN        NaN        NaN        NaN
# 8         NaN                        NaN        NaN        NaN        NaN
# 9         NaN                        NaN        NaN        NaN        NaN
# 10        NaN                        NaN        NaN        NaN        NaN
# 11        NaN                        NaN        NaN        NaN        NaN
# 12        NaN                        NaN        NaN        NaN        NaN
# 13        NaN                        NaN        NaN        NaN        NaN
# 14        NaN                        NaN        NaN        NaN        NaN
# 15        NaN                        NaN        NaN        NaN        NaN
# 16        NaN                        NaN        NaN        NaN        NaN
# 17        NaN                        NaN        NaN        NaN        NaN
# 18        NaN                        NaN        NaN        NaN        NaN
# 19        NaN                        NaN        NaN        NaN        NaN
# 20        NaN                        NaN        NaN        NaN        NaN
# 21        NaN                        NaN        NaN        NaN        NaN
# 22        NaN                        NaN        NaN        NaN        NaN
# 23        NaN                        NaN        NaN        NaN        NaN
# 24        NaN                        NaN        NaN        NaN        NaN
# 25        NaN                        NaN        NaN        NaN        NaN
# 26        NaN                        NaN        NaN        NaN        NaN
# 27        NaN                        NaN        NaN        NaN        NaN
# 28        NaN                        NaN        NaN        NaN        NaN
# 29        NaN                        NaN        NaN        NaN        NaN
# 30        NaN                        NaN        NaN        NaN        NaN
# 31        NaN                        NaN        NaN        NaN        NaN
# 32        NaN                        NaN        NaN        NaN        NaN
# 33        NaN                        NaN        NaN        NaN        NaN
# 34        NaN                        NaN        NaN        NaN        NaN
# 35        NaN                        NaN        NaN        NaN        NaN
# 36        NaN                        NaN        NaN        NaN        NaN
# 37        NaN                        NaN        NaN        NaN        NaN
# 38        NaN                        NaN        NaN        NaN        NaN
# 39        NaN                        NaN        NaN        NaN        NaN
# 40        NaN                        NaN        NaN        NaN        NaN
# 41        NaN                        NaN        NaN        NaN        NaN
# 42   occ_code                   occ_titl      group    tot_emp   emp_prse
# 43    11-0000     Management Occupations      major     133700        1.9
# 44    11-1011           Chief Executives        NaN       9030        4.4
#
#    Unnamed: 8 Unnamed: 9  ... Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 1         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 2         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 3         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 4         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 5         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 6         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 7         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 8         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 9         NaN        NaN  ...         NaN         NaN         NaN         NaN
# 10        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 11        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 12        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 13        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 14        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 15        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 16        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 17        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 18        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 19        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 20        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 21        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 22        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 23        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 24        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 25        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 26        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 27        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 28        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 29        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 30        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 31        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 32        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 33        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 34        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 35        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 36        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 37        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 38        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 39        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 40        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 41        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 42     h_mean     a_mean  ...    h_wpct90    a_wpct10    a_wpct25    a_median
# 43      25.61      53270  ...       47.58       20630       29920       46020
# 44      44.21      91960  ...           #       37230       59640       93130
#
#    Unnamed: 19 Unnamed: 20   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0          NaN         NaN           NaN         NaN         NaN         NaN
# 1          NaN         NaN           NaN         NaN         NaN         NaN
# 2          NaN         NaN           NaN         NaN         NaN         NaN
# 3          NaN         NaN           NaN         NaN         NaN         NaN
# 4          NaN         NaN           NaN         NaN         NaN         NaN
# 5          NaN         NaN           NaN         NaN         NaN         NaN
# 6          NaN         NaN           NaN         NaN         NaN         NaN
# 7          NaN         NaN           NaN         NaN         NaN         NaN
# 8          NaN         NaN           NaN         NaN         NaN         NaN
# 9          NaN         NaN           NaN         NaN         NaN         NaN
# 10         NaN         NaN           NaN         NaN         NaN         NaN
# 11         NaN         NaN           NaN         NaN         NaN         NaN
# 12         NaN         NaN           NaN         NaN         NaN         NaN
# 13         NaN         NaN           NaN         NaN         NaN         NaN
# 14         NaN         NaN           NaN         NaN         NaN         NaN
# 15         NaN         NaN           NaN         NaN         NaN         NaN
# 16         NaN         NaN           NaN         NaN         NaN         NaN
# 17         NaN         NaN           NaN         NaN         NaN         NaN
# 18         NaN         NaN           NaN         NaN         NaN         NaN
# 19         NaN         NaN           NaN         NaN         NaN         NaN
# 20         NaN         NaN           NaN         NaN         NaN         NaN
# 21         NaN         NaN           NaN         NaN         NaN         NaN
# 22         NaN         NaN           NaN         NaN         NaN         NaN
# 23         NaN         NaN           NaN         NaN         NaN         NaN
# 24         NaN         NaN           NaN         NaN         NaN         NaN
# 25         NaN         NaN           NaN         NaN         NaN         NaN
# 26         NaN         NaN           NaN         NaN         NaN         NaN
# 27         NaN         NaN           NaN         NaN         NaN         NaN
# 28         NaN         NaN           NaN         NaN         NaN         NaN
# 29         NaN         NaN           NaN         NaN         NaN         NaN
# 30         NaN         NaN           NaN         NaN         NaN         NaN
# 31         NaN         NaN           NaN         NaN         NaN         NaN
# 32         NaN         NaN           NaN         NaN         NaN         NaN
# 33         NaN         NaN           NaN         NaN         NaN         NaN
# 34         NaN         NaN           NaN         NaN         NaN         NaN
# 35         NaN         NaN           NaN         NaN         NaN         NaN
# 36         NaN         NaN           NaN         NaN         NaN         NaN
# 37         NaN         NaN           NaN         NaN         NaN         NaN
# 38         NaN         NaN           NaN         NaN         NaN         NaN
# 39         NaN         NaN           NaN         NaN         NaN         NaN
# 40         NaN         NaN           NaN         NaN         NaN         NaN
# 41         NaN         NaN           NaN         NaN         NaN         NaN
# 42    a_wpct75    a_wpct90  one or three      annual     release        year
# 43       69490       98970             1         NaN         NaN        1999
# 44      142280           #             1         NaN         NaN        1999
#
# [45 rows x 25 columns]

# %%
# dropping indicies 0 through 41

df_99.drop(index = list(range(42)), inplace = True)

# %%
df_99.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 42       area         st      state   occ_code
# 43         01         AL    Alabama    11-0000
# 44         01         AL    Alabama    11-1011
# 45         01         AL    Alabama    11-1021
# 46         01         AL    Alabama    11-1031
#
#                          Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 42                         occ_titl      group    tot_emp   emp_prse
# 43           Management Occupations      major     133700        1.9
# 44                 Chief Executives        NaN       9030        4.4
# 45  General and Operations Managers        NaN      44460        2.7
# 46                      Legislators        NaN       2060       21.4
#
#    Unnamed: 8 Unnamed: 9  ... Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 42     h_mean     a_mean  ...    h_wpct90    a_wpct10    a_wpct25    a_median
# 43      25.61      53270  ...       47.58       20630       29920       46020
# 44      44.21      91960  ...           #       37230       59640       93130
# 45      26.46      55040  ...       54.02       20720       29480       44660
# 46       7.16      14900  ...        9.16       11140       11780       12850
#
#    Unnamed: 19 Unnamed: 20   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 42    a_wpct75    a_wpct90  one or three      annual     release        year
# 43       69490       98970             1         NaN         NaN        1999
# 44      142280           #             1         NaN         NaN        1999
# 45       73270      112370             1         NaN         NaN        1999
# 46       13930       19060             1         NaN         NaN        1999
#
# [5 rows x 25 columns]

# %%
new_header = df_99.iloc[0] #grab the first row for the header
df_99 = df_99[1:].copy() #take the data less the header row
df_99.columns = new_header #set the header row as the df header

# %%
df_99.head()
# Out:
# 42 area  st    state occ_code                             occ_titl  group  \
# 43   01  AL  Alabama  11-0000               Management Occupations  major
# 44   01  AL  Alabama  11-1011                     Chief Executives    NaN
# 45   01  AL  Alabama  11-1021      General and Operations Managers    NaN
# 46   01  AL  Alabama  11-1031                          Legislators    NaN
# 47   01  AL  Alabama  11-2011  Advertising and Promotions Managers    NaN
#
# 42 tot_emp emp_prse h_mean a_mean  ... h_wpct90 a_wpct10 a_wpct25 a_median  \
# 43  133700      1.9  25.61  53270  ...    47.58    20630    29920    46020
# 44    9030      4.4  44.21  91960  ...        #    37230    59640    93130
# 45   44460      2.7  26.46  55040  ...    54.02    20720    29480    44660
# 46    2060     21.4   7.16  14900  ...     9.16    11140    11780    12850
# 47     980     11.5  18.13  37710  ...    31.81    18210    23030    32170
#
# 42 a_wpct75 a_wpct90 one or three annual release  year
# 43    69490    98970            1    NaN     NaN  1999
# 44   142280        #            1    NaN     NaN  1999
# 45    73270   112370            1    NaN     NaN  1999
# 46    13930    19060            1    NaN     NaN  1999
# 47    47600    66150            1    NaN     NaN  1999
#
# [5 rows x 25 columns]

# %%
features = ['st','occ_code','occ_titl','tot_emp','h_mean','a_mean','year']
df_99 = df_99[features].copy()

# %%
df_99.rename(columns = {'occ_titl':'occ_title'}, inplace = True)

# %%
df_99.head()
# Out:
# 42  st occ_code                            occ_title tot_emp h_mean a_mean  \
# 43  AL  11-0000               Management Occupations  133700  25.61  53270
# 44  AL  11-1011                     Chief Executives    9030  44.21  91960
# 45  AL  11-1021      General and Operations Managers   44460  26.46  55040
# 46  AL  11-1031                          Legislators    2060   7.16  14900
# 47  AL  11-2011  Advertising and Promotions Managers     980  18.13  37710
#
# 42  year
# 43  1999
# 44  1999
# 45  1999
# 46  1999
# 47  1999

# %% [markdown]
# # 2000

# %%
df_00 = pd.read_excel('../data/state_2000_dl.xls')

# %%
df_00.head(45)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                           2000 State OES Estimates        NaN
# 1         NaN                                                NaN        NaN
# 2         NaN    Occupational Employment Statistics (OES) Survey        NaN
# 3         NaN    Bureau of Labor Statistics, Department of Labor        NaN
# 4         NaN              website:    http://stats.bls.gov/oes/        NaN
# 5         NaN                           phone:      202-691-6569        NaN
# 6         NaN                                                NaN        NaN
# 7         NaN                                     Column labels:        NaN
# 8         NaN                      area - fips code of the state        NaN
# 9         NaN                        st - the state abbreviation        NaN
# 10        NaN                             state - the state name        NaN
# 11        NaN  occ_code - a unique, six-digit numerical ident...        NaN
# 12        NaN  occ_title - a descriptive title that correspon...        NaN
# 13        NaN           group - indicates major groups ("major")        NaN
# 14        NaN  tot_emp - the estimated total occupational emp...        NaN
# 15        NaN  emp_prse - the percent relative standard error...        NaN
# 16        NaN  h_mean - mean hourly wage, the estimated total...        NaN
# 17        NaN  a_mean - mean annual wage, the estimated mean ...        NaN
# 18        NaN  mean_prse - the percent relative standard erro...        NaN
# 19        NaN  h_wpct10 - the 10% percentile hourly wage (10%...        NaN
# 20        NaN          h_wpct25 - the 25% percentile hourly wage        NaN
# 21        NaN  h_median - the median (50% percentile) hourly ...        NaN
# 22        NaN          h_wpct75 - the 75% percentile hourly wage        NaN
# 23        NaN          h_wpct90 - the 90% percentile hourly wage        NaN
# 24        NaN  a_wpct10 - the 10% percentile annual wage (10%...        NaN
# 25        NaN          a_wpct25 - the 25% percentile annual wage        NaN
# 26        NaN  a_median - the median (50% percentile) annual ...        NaN
# 27        NaN          a_wpct75 - the 75% percentile annual wage        NaN
# 28        NaN          a_wpct90 - the 90% percentile annual wage        NaN
# 29        NaN  annual - "true" identifies occupations for whi...        NaN
# 30        NaN  release - "no" indicates that no wage or emplo...        NaN
# 31        NaN  year - year the data were collected; some of t...        NaN
# 32        NaN                                                NaN        NaN
# 33        NaN                                             Notes:        NaN
# 34        NaN  * = indicates that a wage estimate is not avai...        NaN
# 35        NaN  ** = indicates that an employment estimate is ...        NaN
# 36        NaN  *** = The wage data for two occupations, airli...        NaN
# 37        NaN  # = indicates a wage greater than $70.00 per h...        NaN
# 38        NaN  Relative Standard Error (RSE) is a measure of ...        NaN
# 39        NaN  Estimates for residual, "All Other . . .," occ...        NaN
# 40        NaN                                                NaN        NaN
# 41       area                                                 st      state
# 42         01                                                 AL    Alabama
# 43         01                                                 AL    Alabama
# 44         01                                                 AL    Alabama
#
#    Unnamed: 3                       Unnamed: 4 Unnamed: 5    Unnamed: 6  \
# 0         NaN                              NaN        NaN           NaN
# 1         NaN                              NaN        NaN           NaN
# 2         NaN                              NaN        NaN           NaN
# 3         NaN                              NaN        NaN           NaN
# 4         NaN                              NaN        NaN           NaN
# 5         NaN                              NaN        NaN           NaN
# 6         NaN                              NaN        NaN           NaN
# 7         NaN                              NaN        NaN           NaN
# 8         NaN                              NaN        NaN           NaN
# 9         NaN                              NaN        NaN           NaN
# 10        NaN                              NaN        NaN           NaN
# 11        NaN                              NaN        NaN           NaN
# 12        NaN                              NaN        NaN           NaN
# 13        NaN                              NaN        NaN           NaN
# 14        NaN                              NaN        NaN           NaN
# 15        NaN                              NaN        NaN           NaN
# 16        NaN                              NaN        NaN           NaN
# 17        NaN                              NaN        NaN           NaN
# 18        NaN                              NaN        NaN           NaN
# 19        NaN                              NaN        NaN           NaN
# 20        NaN                              NaN        NaN           NaN
# 21        NaN                              NaN        NaN           NaN
# 22        NaN                              NaN        NaN           NaN
# 23        NaN                              NaN        NaN           NaN
# 24        NaN                              NaN        NaN           NaN
# 25        NaN                              NaN        NaN           NaN
# 26        NaN                              NaN        NaN           NaN
# 27        NaN                              NaN        NaN           NaN
# 28        NaN                              NaN        NaN           NaN
# 29        NaN                              NaN        NaN           NaN
# 30        NaN                              NaN        NaN           NaN
# 31        NaN                              NaN        NaN           NaN
# 32        NaN                              NaN        NaN           NaN
# 33        NaN                              NaN        NaN           NaN
# 34        NaN                              NaN        NaN           NaN
# 35        NaN                              NaN        NaN           NaN
# 36        NaN                              NaN        NaN           NaN
# 37        NaN                              NaN        NaN           NaN
# 38        NaN                              NaN        NaN           NaN
# 39        NaN                              NaN        NaN           NaN
# 40        NaN                              NaN        NaN           NaN
# 41   occ_code                         occ_titl      group       tot_emp
# 42    11-0000           Management Occupations      major        120380
# 43    11-1011                 Chief Executives        NaN          6090
# 44    11-1021  General and Operations Managers        NaN         38020
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 5         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 6         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 7         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 8         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 9         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 10        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 11        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 12        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 13        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 14        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 15        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 16        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 17        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 18        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 19        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 20        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 21        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 22        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 23        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 24        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 25        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 26        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 27        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 28        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 29        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 30        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 31        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 32        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 33        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 34        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 35        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 36        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 37        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 38        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 39        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 40        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 41   emp_prse     h_mean     a_mean  ...    h_wpct75    h_wpct90    a_wpct10
# 42        1.7      27.67      57560  ...       36.38       50.76       22530
# 43        3.7      48.26     100380  ...           #           #       43650
# 44        2.6      28.29      58840  ...       37.94       55.36       22230
#
#    Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN         NaN         NaN
# 39         NaN         NaN         NaN         NaN         NaN         NaN
# 40         NaN         NaN         NaN         NaN         NaN         NaN
# 41    a_wpct25    a_median    a_wpct75    a_wpct90      annual     release
# 42       33310       51620       75680      105590         NaN         NaN
# 43       67190      107050           #           #         NaN         NaN
# 44       32540       50400       78920      115160         NaN         NaN
#
#    Unnamed: 23
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41        year
# 42        2000
# 43        2000
# 44        2000
#
# [45 rows x 24 columns]

# %%
# dropping indicies 0 through 40

df_00.drop(index = list(range(41)), inplace = True)

# %%
df_00.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 41       area         st      state   occ_code
# 42         01         AL    Alabama    11-0000
# 43         01         AL    Alabama    11-1011
# 44         01         AL    Alabama    11-1021
# 45         01         AL    Alabama    11-1031
#
#                          Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7  \
# 41                         occ_titl      group       tot_emp   emp_prse
# 42           Management Occupations      major        120380        1.7
# 43                 Chief Executives        NaN          6090        3.7
# 44  General and Operations Managers        NaN         38020        2.6
# 45                      Legislators        NaN          1220       20.8
#
#    Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 41     h_mean     a_mean  ...    h_wpct75    h_wpct90    a_wpct10    a_wpct25
# 42      27.67      57560  ...       36.38       50.76       22530       33310
# 43      48.26     100380  ...           #           #       43650       67190
# 44      28.29      58840  ...       37.94       55.36       22230       32540
# 45       8.48      17640  ...        8.31       14.32       11520       12340
#
#    Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23
# 41    a_median    a_wpct75    a_wpct90      annual     release        year
# 42       51620       75680      105590         NaN         NaN        2000
# 43      107050           #           #         NaN         NaN        2000
# 44       50400       78920      115160         NaN         NaN        2000
# 45       13720       17280       29790         NaN         NaN        2000
#
# [5 rows x 24 columns]

# %%
new_header = df_00.iloc[0] #grab the first row for the header
df_00 = df_00[1:].copy() #take the data less the header row
df_00.columns = new_header #set the header row as the df header

# %%
df_00.head()
# Out:
# 41 area  st    state occ_code                             occ_titl  group  \
# 42   01  AL  Alabama  11-0000               Management Occupations  major
# 43   01  AL  Alabama  11-1011                     Chief Executives    NaN
# 44   01  AL  Alabama  11-1021      General and Operations Managers    NaN
# 45   01  AL  Alabama  11-1031                          Legislators    NaN
# 46   01  AL  Alabama  11-2011  Advertising and Promotions Managers    NaN
#
# 41       tot_emp emp_prse   h_mean     a_mean  ... h_wpct75 h_wpct90 a_wpct10  \
# 42        120380      1.7    27.67      57560  ...    36.38    50.76    22530
# 43          6090      3.7    48.26     100380  ...        #        #    43650
# 44         38020      2.6    28.29      58840  ...    37.94    55.36    22230
# 45          1220     20.8     8.48      17640  ...     8.31    14.32    11520
# 46           800      6.3    20.70      43050  ...    25.98    38.33    19630
#
# 41 a_wpct25   a_median a_wpct75 a_wpct90 annual release  year
# 42    33310      51620    75680   105590    NaN     NaN  2000
# 43    67190     107050        #        #    NaN     NaN  2000
# 44    32540      50400    78920   115160    NaN     NaN  2000
# 45    12340      13720    17280    29790    NaN     NaN  2000
# 46    26060      35510    54030    79720    NaN     NaN  2000
#
# [5 rows x 24 columns]

# %%
features = ['st','occ_code','occ_titl','tot_emp','h_mean','a_mean','year']
df_00 = df_00[features].copy()

# %%
df_00.head()
# Out:
# 41  st occ_code                             occ_titl       tot_emp   h_mean  \
# 42  AL  11-0000               Management Occupations        120380    27.67
# 43  AL  11-1011                     Chief Executives          6090    48.26
# 44  AL  11-1021      General and Operations Managers         38020    28.29
# 45  AL  11-1031                          Legislators          1220     8.48
# 46  AL  11-2011  Advertising and Promotions Managers           800    20.70
#
# 41     a_mean  year
# 42      57560  2000
# 43     100380  2000
# 44      58840  2000
# 45      17640  2000
# 46      43050  2000

# %%
df_00.rename(columns = {'occ_titl':'occ_title'}, inplace = True)

# %% [markdown]
# # 2001

# %%
df_01 = pd.read_excel('../data/state_2001_dl.xls')

# %%
df_01.head()
# Out:
#    area  st    state occ_code                        occ_title  group  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management Occupations  major
# 2     1  AL  Alabama  11-1011                 Chief Executives    NaN
# 3     1  AL  Alabama  11-1021  General and Operations Managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    tot_emp emp_prse h_mean  a_mean  ... h_median h_wpct75 h_wpct90 a_wpct10  \
# 0  1827960      0.5   14.2   29530  ...    11.02    17.52    26.04    12950
# 1   107460      1.3  29.33   61000  ...    26.44    38.52    53.51    24690
# 2     5290      2.9  49.69  103350  ...    53.72        #        #    46510
# 3    33420      2.1  30.85   64170  ...    26.76    41.49    60.86    25430
# 4     1740     21.2   7.58   15760  ...     6.44     7.25    10.01    11510
#
#   a_wpct25 a_median a_wpct75 a_wpct90 annual  year
# 0    15950    22910    36450    54160    NaN  2001
# 1    36400    55000    80110   111300    NaN  2001
# 2    71520   111740        #        #    NaN  2001
# 3    36400    55660    86300   126580    NaN  2001
# 4    12220    13400    15070    20820    NaN  2001
#
# [5 rows x 23 columns]

# %%
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean','year']
df_01 = df_01[features].copy()

# %%
df_01.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1827960   14.2   29530  2001
# 1  AL  11-0000           Management Occupations   107460  29.33   61000  2001
# 2  AL  11-1011                 Chief Executives     5290  49.69  103350  2001
# 3  AL  11-1021  General and Operations Managers    33420  30.85   64170  2001
# 4  AL  11-1031                      Legislators     1740   7.58   15760  2001

# %% [markdown]
# # 2002

# %%
df_02 = pd.read_excel('../data/state_2002_dl.xls')

# %%
df_02.head()
# Out:
#    area  st    state occ_code                        occ_title  group  \
# 0     1  AL  Alabama  00-0000                  All Occupations  major
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    tot_emp emp_prse h_mean  a_mean  ... h_wpct25 h_median h_wpct75 h_wpct90  \
# 0  1819390      0.5  14.88   30940  ...     7.89    11.37    18.13    26.94
# 1   103720      1.2  32.19   66960  ...    18.48    27.93    40.33    56.54
# 2     5340      2.8  60.22  125260  ...    35.21     56.3        #        #
# 3    31660      1.8  34.63   72040  ...     18.8    28.53    43.53    65.57
# 4     1730     20.7   7.71   16030  ...     6.05     6.64     7.51     9.73
#
#   a_wpct10 a_wpct25 a_median a_wpct75 a_wpct90 annual
# 0    13250    16420    23640    37710    56040    NaN
# 1    26200    38450    58100    83880   117600    NaN
# 2    44940    73230   117110        #        #    NaN
# 3    27110    39100    59350    90540   136390    NaN
# 4    11820    12590    13820    15620    20240    NaN
#
# [5 rows x 22 columns]

# %%
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_02 = df_02[features].copy()

# %%
df_02['year'] = [2002 for i in range(len(df_02))]

# %%
df_02.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1819390  14.88   30940  2002
# 1  AL  11-0000           Management occupations   103720  32.19   66960  2002
# 2  AL  11-1011                 Chief executives     5340  60.22  125260  2002
# 3  AL  11-1021  General and operations managers    31660  34.63   72040  2002
# 4  AL  11-1031                      Legislators     1730   7.71   16030  2002

# %% [markdown]
# # 2003

# %%
df_03 = pd.read_excel('../data/state_may2003_dl.xls')

# %%
df_03.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE H_MEAN  A_MEAN  ... H_PCT25 H_MEDIAN H_PCT75 H_PCT90  \
# 0  1820170      0.5  15.06   31330  ...    7.97    11.52   18.33   27.23
# 1    91920      1.2  34.58   71920  ...   20.59    30.27   42.96   60.24
# 2     4460      3.5  65.17  135560  ...   40.84    63.15       #       #
# 3    27570      1.9  37.87   78770  ...   21.52    31.79   46.90       #
# 4     1530     22.8   7.95   16550  ...    6.08     6.68    7.67    9.57
#
#   A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL
# 0   13250   16580    23960   38140   56650    NaN
# 1   29230   42820    62960   89360  125290    NaN
# 2   53720   84950   131360       #       #    NaN
# 3   31750   44770    66130   97550       #    NaN
# 4   11900   12650    13880   15960   19900    NaN
#
# [5 rows x 22 columns]

# %%
new_cols = [x.lower() for x in df_03.columns]

# %%
df_03.columns = new_cols

# %%
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_03 = df_03[features].copy()

# %%
df_03['year'] = [2003 for i in range(len(df_03))]

# %%
df_03.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1820170  15.06   31330  2003
# 1  AL  11-0000           Management occupations    91920  34.58   71920  2003
# 2  AL  11-1011                 Chief executives     4460  65.17  135560  2003
# 3  AL  11-1021  General and operations managers    27570  37.87   78770  2003
# 4  AL  11-1031                      Legislators     1530   7.95   16550  2003

# %% [markdown]
# # 2004

# %%
df_04 = pd.read_excel('../data/state_may2004_dl.xls')

# %%
df_04.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1830360      0.6  15.19   31590  ...    11.76   18.48   27.20   13320
# 1    81040      1.3  36.58   76100  ...    31.73   44.65   65.81   32510
# 2     3880      3.8  64.87  134930  ...    64.69       #       #   50150
# 3    25990      2.0  41.31   85920  ...    34.29   52.51       #   35570
# 4     1590     23.1      *   16600  ...        *       *       *   11880
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   16910    24470   38430   56570    NaN    NaN
# 1   46480    66000   92860  136890    NaN    NaN
# 2   87420   134560       #       #    NaN    NaN
# 3   48260    71330  109210       #    NaN    NaN
# 4   12610    13840   16200   22250   True    NaN
#
# [5 rows x 23 columns]

# %%
new_cols = [x.lower() for x in df_04.columns]
df_04.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_04 = df_04[features].copy()
df_04['year'] = [2004 for i in range(len(df_04))]

# %%
df_04.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1830360  15.19   31590  2004
# 1  AL  11-0000           Management occupations    81040  36.58   76100  2004
# 2  AL  11-1011                 Chief executives     3880  64.87  134930  2004
# 3  AL  11-1021  General and operations managers    25990  41.31   85920  2004
# 4  AL  11-1031                      Legislators     1590      *   16600  2004

# %% [markdown]
# # 2005

# %%
df_05 = pd.read_excel('../data/state_may2005_dl.xls')

# %%
df_05.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1872600      0.6  15.54   32310  ...    12.07   18.91   27.76   13400
# 1    79730      1.2  37.12   77210  ...    32.39   45.48   66.80   33340
# 2     3300      4.0  63.63  132350  ...    64.39       #       #   47060
# 3    27450      1.4  41.57   86460  ...    34.44   53.07       #   36100
# 4     1730     15.7      *   14700  ...        *       *       *   11330
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   17250    25110   39330   57740    NaN    NaN
# 1   47420    67370   94600  138950    NaN    NaN
# 2   83380   133940       #       #    NaN    NaN
# 3   48620    71630  110380       #    NaN    NaN
# 4   11950    12980   14010   20430   True    NaN
#
# [5 rows x 23 columns]

# %%
new_cols = [x.lower() for x in df_05.columns]
df_05.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_05 = df_05[features].copy()
df_05['year'] = [2005 for i in range(len(df_05))]

# %%
df_05.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1872600  15.54   32310  2005
# 1  AL  11-0000           Management occupations    79730  37.12   77210  2005
# 2  AL  11-1011                 Chief executives     3300  63.63  132350  2005
# 3  AL  11-1021  General and operations managers    27450  41.57   86460  2005
# 4  AL  11-1031                      Legislators     1730      *   14700  2005

# %% [markdown]
# # 2006

# %%
df_06 = pd.read_excel('../data/state_may2006_dl.xls')

# %%
df_06.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1912220      0.6  16.08   33440  ...    12.49   19.52   29.02   13730
# 1    77880      1.4  38.78   80660  ...    33.80   47.75       #   35100
# 2     2700      3.8  68.18  141810  ...    68.35       #       #   61630
# 3    28780      1.4  43.00   89440  ...    36.03   54.41       #   38390
# 4     2010     15.8      *   15200  ...        *       *       *   11490
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   17800    25980   40610   60350    NaN    NaN
# 1   49590    70310   99320       #    NaN    NaN
# 2   91420   142170       #       #    NaN    NaN
# 3   51510    74940  113170       #    NaN    NaN
# 4   12200    13370   14600   21300   True    NaN
#
# [5 rows x 23 columns]

# %%
new_cols = [x.lower() for x in df_06.columns]
df_06.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_06 = df_06[features].copy()
df_06['year'] = [2006 for i in range(len(df_06))]

# %%
df_06.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1912220  16.08   33440  2006
# 1  AL  11-0000           Management occupations    77880  38.78   80660  2006
# 2  AL  11-1011                 Chief executives     2700  68.18  141810  2006
# 3  AL  11-1021  General and operations managers    28780  43.00   89440  2006
# 4  AL  11-1031                      Legislators     2010      *   15200  2006

# %% [markdown]
# # 2007

# %%
df_07 = pd.read_excel('../data/state_may2007_dl.xls')

# %%
df_07.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1931970      0.5  16.80   34950  ...    13.11   20.44   30.27   14010
# 1    78560      1.1  40.71   84680  ...    35.43   50.48       #   36570
# 2     3470      3.2  71.00  147680  ...    68.15       #       #   64710
# 3    30850      1.4  43.61   90720  ...    36.37   55.01       #   39620
# 4     1950     12.3      *   15630  ...        *       *       *   11740
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   18430    27260   42520   62950    NaN    NaN
# 1   51960    73700  104990       #    NaN    NaN
# 2   93170   141750       #       #    NaN    NaN
# 3   53340    75660  114410       #    NaN    NaN
# 4   12500    13770   15090   21220   True    NaN
#
# [5 rows x 23 columns]

# %%
new_cols = [x.lower() for x in df_07.columns]
df_07.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_07 = df_07[features].copy()
df_07['year'] = [2007 for i in range(len(df_07))]

# %%
df_07.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1931970  16.80   34950  2007
# 1  AL  11-0000           Management occupations    78560  40.71   84680  2007
# 2  AL  11-1011                 Chief executives     3470  71.00  147680  2007
# 3  AL  11-1021  General and operations managers    30850  43.61   90720  2007
# 4  AL  11-1031                      Legislators     1950      *   15630  2007

# %% [markdown]
# # 2008

# %%
df_08 = pd.read_excel('../data/state__M2008_dl.xls')

# %%
df_08.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations    NaN
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1945300      0.4  17.39   36170  ...    13.53   21.19   31.23   14820
# 1    79400      0.9  42.41   88210  ...    36.75   52.02   75.47   38690
# 2     3630      3.7  75.62  157290  ...    73.07       #       #   65680
# 3    33500      1.3  44.39   92330  ...    37.03   54.55       #   41090
# 4     1580      6.2      *   17180  ...        *       *       *   12900
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   18970    28140   44070   64950    NaN    NaN
# 1   54430    76450  108210  156970    NaN    NaN
# 2  100680   151990       #       #    NaN    NaN
# 3   54960    77010  113470       #    NaN    NaN
# 4   13640    14880   16240   23080   True    NaN
#
# [5 rows x 23 columns]

# %%
new_cols = [x.lower() for x in df_08.columns]
df_08.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_08 = df_08[features].copy()
df_08['year'] = [2008 for i in range(len(df_08))]

# %%
df_08.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1945300  17.39   36170  2008
# 1  AL  11-0000           Management occupations    79400  42.41   88210  2008
# 2  AL  11-1011                 Chief executives     3630  75.62  157290  2008
# 3  AL  11-1021  General and operations managers    33500  44.39   92330  2008
# 4  AL  11-1031                      Legislators     1580      *   17180  2008

# %% [markdown]
# # 2009

# %%
df_09 = pd.read_excel('../data/state_dl.xls')

# %%
df_09.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations  total
# 1     1  AL  Alabama  11-0000           Management occupations  major
# 2     1  AL  Alabama  11-1011                 Chief executives    NaN
# 3     1  AL  Alabama  11-1021  General and operations managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE JOBS_1000 H_MEAN  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1863620      0.4  1000.000  18.03  ...    13.95   22.01   32.20   15550
# 1    75100      1.0    40.298  44.06  ...    37.92   53.94   77.24   40540
# 2     2960      3.5     1.589  79.98  ...    77.32       #       #   70060
# 3    33390      1.4    17.916  46.09  ...    38.03   56.43       #   42470
# 4     1350      5.1     0.725      *  ...        *       *       *   14090
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   19410    29020   45770   66980    NaN    NaN
# 1   56100    78870  112190  160660    NaN    NaN
# 2  105360   160830       #       #    NaN    NaN
# 3   56280    79090  117360       #    NaN    NaN
# 4   14720    15780   18590   26680   True    NaN
#
# [5 rows x 24 columns]

# %%
new_cols = [x.lower() for x in df_09.columns]
df_09.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_09 = df_09[features].copy()
df_09['year'] = [2009 for i in range(len(df_09))]

# %%
df_09.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1863620  18.03   37500  2009
# 1  AL  11-0000           Management occupations    75100  44.06   91650  2009
# 2  AL  11-1011                 Chief executives     2960  79.98  166350  2009
# 3  AL  11-1021  General and operations managers    33390  46.09   95880  2009
# 4  AL  11-1031                      Legislators     1350      *   18840  2009

# %% [markdown]
# # 2010

# %%
df_10 = pd.read_excel('../data/state_M2010_dl.xls')

# %%
df_10.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations  total
# 1     1  AL  Alabama  11-0000           Management Occupations  major
# 2     1  AL  Alabama  11-1011                 Chief Executives    NaN
# 3     1  AL  Alabama  11-1021  General and Operations Managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC QUOTIENT  ... H_MEDIAN H_PCT75 H_PCT90  \
# 0  1807480      0.4      1000            1  ...    14.21   22.57    33.5
# 1    69180        1    38.274        0.808  ...    40.04   56.44       #
# 2     1750      4.8     0.971        0.451  ...        #       #       #
# 3    30870      1.3     17.08        1.271  ...    40.93   60.51       #
# 4     1200      4.4     0.663        1.282  ...        *       *       *
#
#   A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   16470   19630    29570   46940   69670    NaN    NaN
# 1   44140   60540    83290  117390       #    NaN    NaN
# 2   85270  120370        #       #       #    NaN    NaN
# 3   46240   60700    85130  125860       #    NaN    NaN
# 4   15570   15930    17150   19060   24540   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_10.columns]
df_10.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_10 = df_10[features].copy()
df_10['year'] = [2010 for i in range(len(df_10))]

# %%
df_10.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1807480  18.55   38590  2010
# 1  AL  11-0000           Management Occupations    69180  46.39   96480  2010
# 2  AL  11-1011                 Chief Executives     1750  89.14  185420  2010
# 3  AL  11-1021  General and Operations Managers    30870  49.37  102690  2010
# 4  AL  11-1031                      Legislators     1200      *   19450  2010

# %% [markdown]
# # 2011

# %%
df_11 = pd.read_excel('../data/state_M2011_dl.xls')

# %%
df_11.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE  GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations  total
# 1     1  AL  Alabama  11-0000           Management Occupations  major
# 2     1  AL  Alabama  11-1011                 Chief Executives    NaN
# 3     1  AL  Alabama  11-1021  General and Operations Managers    NaN
# 4     1  AL  Alabama  11-1031                      Legislators    NaN
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1809420      0.4      1000     1  ...    14.35   22.91   34.18   17110
# 1    66050        1    36.502  0.76  ...    42.28   58.36   81.81   48550
# 2     1530      8.9     0.847  0.41  ...    79.13       #       #   85410
# 3    28220      1.4    15.596  1.11  ...     44.5   65.23       #   51490
# 4     1140      5.4      0.63   1.3  ...        *       *       *   15960
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   19910    29850   47650   71100    NaN    NaN
# 1   64680    87940  121400  170170    NaN    NaN
# 2  112460   164590       #       #    NaN    NaN
# 3   66670    92570  135670       #    NaN    NaN
# 4   16760    18100   19470   27760   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_11.columns]
df_11.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_11 = df_11[features].copy()
df_11['year'] = [2011 for i in range(len(df_11))]

# %%
df_11.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1809420  18.84   39180  2011
# 1  AL  11-0000           Management Occupations    66050  48.32  100500  2011
# 2  AL  11-1011                 Chief Executives     1530  85.87  178610  2011
# 3  AL  11-1021  General and Operations Managers    28220  52.82  109870  2011
# 4  AL  11-1031                      Legislators     1140      *   20340  2011

# %% [markdown]
# # 2012

# %%
df_12 = pd.read_excel('../data/state_M2012_dl.xls')

# %%
df_12.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1824400      0.4      1000     1  ...     14.4   23.12   34.73   17150
# 1    66790        1    36.608  0.75  ...    43.21   59.64   83.37   49870
# 2     1330       10     0.727  0.37  ...    80.98       #       #   86540
# 3    27040      1.5    14.822  1.02  ...    47.09   69.04       #   54870
# 4     1070      6.5     0.584  1.34  ...        *       *       *   16010
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   19850    29950   48090   72230    NaN    NaN
# 1   66520    89870  124060  173420    NaN    NaN
# 2  113020   168450       #       #    NaN    NaN
# 3   71140    97950  143600       #    NaN    NaN
# 4   16860    18270   19850   26680   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_12.columns]
df_12.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_12 = df_12[features].copy()
df_12['year'] = [2012 for i in range(len(df_12))]

# %%
df_12.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1824400  19.01   39550  2012
# 1  AL  11-0000           Management Occupations    66790  49.24  102420  2012
# 2  AL  11-1011                 Chief Executives     1330  86.38  179680  2012
# 3  AL  11-1021  General and Operations Managers    27040  55.58  115610  2012
# 4  AL  11-1031                      Legislators     1070      *   19860  2012

# %% [markdown]
# # 2013

# %%
df_13 = pd.read_excel('../data/state_M2013_dl.xls')

# %%
df_13.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1844080      0.4      1000     1  ...    14.61   23.64    35.4   17200
# 1    66820      1.1    36.233  0.73  ...    44.53   61.52   86.05   51190
# 2     1300     11.1     0.705  0.38  ...    83.98       #       #   87940
# 3    26490      1.7    14.364  0.96  ...    49.06   71.18       #   58470
# 4     1400      9.8      0.76  1.81  ...        *       *       *   16110
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   20010    30390   49180   73620    NaN    NaN
# 1   68650    92610  127970  178980    NaN    NaN
# 2  117790   174690       #       #    NaN    NaN
# 3   74340   102050  148050       #    NaN    NaN
# 4   17010    18510   21340   36190   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_13.columns]
df_13.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_13 = df_13[features].copy()
df_13['year'] = [2013 for i in range(len(df_13))]

# %%
df_13.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1844080  19.35   40240  2013
# 1  AL  11-0000           Management Occupations    66820  50.77  105600  2013
# 2  AL  11-1011                 Chief Executives     1300  88.34  183750  2013
# 3  AL  11-1021  General and Operations Managers    26490  57.62  119850  2013
# 4  AL  11-1031                      Legislators     1400      *   22660  2013

# %% [markdown]
# # 2014

# %%
df_14 = pd.read_excel('../data/state_M2014_dl.xlsx')

# %%
df_14.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1857530      0.4      1000     1  ...    14.83   23.95   36.04   17260
# 1    67500      1.1    36.338  0.73  ...    44.98   62.09   88.43   51050
# 2     1080      4.8      0.58  0.32  ...        #       #       #  108270
# 3    26480      1.5    14.258  0.94  ...       49   71.44       #   57510
# 4     1470      8.7      0.79  1.94  ...        *       *       *   16120
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   20220    30850   49810   74950    NaN    NaN
# 1   68830    93550  129150  183940    NaN    NaN
# 2  140570        #       #       #    NaN    NaN
# 3   74390   101930  148590       #    NaN    NaN
# 4   17000    18450   20670   32820   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_14.columns]
df_14.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_14 = df_14[features].copy()
df_14['year'] = [2014 for i in range(len(df_14))]

# %%
df_14.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1857530  19.66   40890  2014
# 1  AL  11-0000           Management Occupations    67500  51.48  107080  2014
# 2  AL  11-1011                 Chief Executives     1080  97.67  203150  2014
# 3  AL  11-1021  General and Operations Managers    26480     58  120640  2014
# 4  AL  11-1031                      Legislators     1470      *   21920  2014

# %% [markdown]
# # 2015

# %%
df_15 = pd.read_excel('../data/state_M2015_dl.xlsx')

# %%
df_15.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1883310      0.4      1000     1  ...    15.17   24.39   36.88   17380
# 1    69100        1    36.689  0.73  ...     45.9   63.15       #   52320
# 2     1100      4.1     0.587  0.34  ...        #       #       #  109410
# 3    27240      1.4    14.466  0.93  ...     49.2   71.98       #   57800
# 4     1430      8.7      0.76  1.88  ...        *       *       *   16110
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   20650    31550   50730   76720    NaN    NaN
# 1   70120    95470  131360       #    NaN    NaN
# 2  145150        #       #       #    NaN    NaN
# 3   74950   102330  149720       #    NaN    NaN
# 4   16960    18380   20200   32120   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_15.columns]
df_15.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_15 = df_15[features].copy()
df_15['year'] = [2015 for i in range(len(df_15))]

# %%
df_15.head()
# Out:
#    st occ_code                        occ_title  tot_emp  h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1883310   20.15   41920  2015
# 1  AL  11-0000           Management Occupations    69100   52.79  109800  2015
# 2  AL  11-1011                 Chief Executives     1100  101.21  210530  2015
# 3  AL  11-1021  General and Operations Managers    27240   58.85  122410  2015
# 4  AL  11-1031                      Legislators     1430       *   22690  2015

# %% [markdown]
# # 2016

# %%
df_16 = pd.read_excel('../data/state_M2016_dl.xlsx')

# %%
df_16.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1912990      0.4      1000     1  ...    15.43    24.7    37.4   17580
# 1    70090        1    36.639  0.73  ...    46.09   63.18   90.25   52470
# 2     1030      5.5     0.538  0.34  ...    94.59       #       #   98310
# 3    26930      1.4    14.077   0.9  ...    49.53   71.49       #   55770
# 4     1210      8.9     0.635  1.66  ...        *       *       *   16180
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   21200    32100   51370   77780    NaN    NaN
# 1   70040    95870  131410  187720    NaN    NaN
# 2  137140   196750       #       #    NaN    NaN
# 3   74270   103030  148710       #    NaN    NaN
# 4   17070    18560   21590   37320   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_16.columns]
df_16.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_16 = df_16[features].copy()
df_16['year'] = [2016 for i in range(len(df_16))]

# %%
df_16.head()
# Out:
#    st occ_code                        occ_title  tot_emp  h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1912990   20.44   42510  2016
# 1  AL  11-0000           Management Occupations    70090   52.98  110210  2016
# 2  AL  11-1011                 Chief Executives     1030  100.63  209300  2016
# 3  AL  11-1021  General and Operations Managers    26930   58.86  122420  2016
# 4  AL  11-1031                      Legislators     1210       *   23390  2016

# %% [markdown]
# # 2017

# %%
df_17 = pd.read_excel('../data/state_M2017_dl.xlsx')

# %%
df_17.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1922570      0.4      1000     1  ...    15.77   25.01   37.83   17770
# 1    69950        1    36.385  0.71  ...    46.63   64.12    90.8   52130
# 2     1120        6     0.585   0.4  ...    94.45       #       #   84520
# 3    27150      1.6    14.123  0.91  ...    49.19   71.09       #   54040
# 4     1100       12     0.572  1.59  ...        *       *       *   16310
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   21740    32800   52020   78690    NaN    NaN
# 1   70130    96980  133360  188860    NaN    NaN
# 2  125290   196460       #       #    NaN    NaN
# 3   72610   102320  147860       #    NaN    NaN
# 4   17280    18910   24630   47510   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_17.columns]
df_17.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_17 = df_17[features].copy()
df_17['year'] = [2017 for i in range(len(df_17))]

# %%
df_17.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1922570  20.76   43170  2017
# 1  AL  11-0000           Management Occupations    69950  53.44  111150  2017
# 2  AL  11-1011                 Chief Executives     1120  99.56  207090  2017
# 3  AL  11-1021  General and Operations Managers    27150  58.04  120730  2017
# 4  AL  11-1031                      Legislators     1100      *   25410  2017

# %% [markdown]
# # 2018

# %%
df_18 = pd.read_excel('../data/state_M2018_dl.xlsx')

# %%
df_18.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1943760      0.4      1000     1  ...    16.22   25.63   38.28   18030
# 1    73860      1.1    38.001  0.72  ...    46.01   63.87   90.06   48650
# 2     1390      5.6     0.716  0.53  ...    91.31       #       #   79530
# 3    28600      1.8    14.712  0.93  ...    48.55   70.79       #   50180
# 4      970      6.4     0.498  1.43  ...        *       *       *   16310
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   22400    33740   53310   79630    NaN    NaN
# 1   68030    95710  132860  187330    NaN    NaN
# 2  125570   189920       #       #    NaN    NaN
# 3   68990   100980  147250       #    NaN    NaN
# 4   17390    19210   32290   63390   True    NaN
#
# [5 rows x 25 columns]

# %%
new_cols = [x.lower() for x in df_18.columns]
df_18.columns = new_cols
features = ['st','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_18 = df_18[features].copy()
df_18['year'] = [2018 for i in range(len(df_18))]

# %%
df_18.head()
# Out:
#    st occ_code                        occ_title  tot_emp h_mean  a_mean  year
# 0  AL  00-0000                  All Occupations  1943760  21.05   43790  2018
# 1  AL  11-0000           Management Occupations    73860  52.73  109680  2018
# 2  AL  11-1011                 Chief Executives     1390  98.36  204590  2018
# 3  AL  11-1021  General and Operations Managers    28600  56.94  118440  2018
# 4  AL  11-1031                      Legislators      970      *   31760  2018

# %% [markdown]
# # 2019

# %%
df_19 = pd.read_excel('../data/state_M2019_dl.xlsx')

# %%
df_19.head()
# Out:
#    area area_title  area_type  naics     naics_title         i_group  \
# 0     1    Alabama          2      0  Cross-industry  cross-industry
# 1     1    Alabama          2      0  Cross-industry  cross-industry
# 2     1    Alabama          2      0  Cross-industry  cross-industry
# 3     1    Alabama          2      0  Cross-industry  cross-industry
# 4     1    Alabama          2      0  Cross-industry  cross-industry
#
#    own_code occ_code                        occ_title   o_group  ... h_median  \
# 0      1235  00-0000                  All Occupations     total  ...    16.73
# 1      1235  11-0000           Management Occupations     major  ...    45.03
# 2      1235  11-1011                 Chief Executives  detailed  ...    86.91
# 3      1235  11-1021  General and Operations Managers  detailed  ...    47.42
# 4      1235  11-1031                      Legislators  detailed  ...        *
#
#   h_pct75 h_pct90 a_pct10  a_pct25 a_median a_pct75 a_pct90 annual hourly
# 0   26.34   39.26   18270    23000    34800   54790   81660    NaN    NaN
# 1   63.07   90.16   47250    66140    93660  131180  187530    NaN    NaN
# 2       #       #   68630   115110   180780       #       #    NaN    NaN
# 3   70.48       #   48240    66370    98630  146610       #    NaN    NaN
# 4       *       *   16200    17210    18880   28660   55220   True    NaN
#
# [5 rows x 30 columns]

# %%
features = ['area_title','occ_code','occ_title','tot_emp','h_mean','a_mean']
df_19 = df_19[features].copy()
df_19['year'] = [2019 for i in range(len(df_19))]

# %%
df_19.head()
# Out:
#   area_title occ_code                        occ_title  tot_emp h_mean  \
# 0    Alabama  00-0000                  All Occupations  1974170   21.6
# 1    Alabama  11-0000           Management Occupations    83760  51.86
# 2    Alabama  11-1011                 Chief Executives     1320  92.84
# 3    Alabama  11-1021  General and Operations Managers    30790  56.41
# 4    Alabama  11-1031                      Legislators     1110      *
#
#    a_mean  year
# 0   44930  2019
# 1  107860  2019
# 2  193110  2019
# 3  117340  2019
# 4   29130  2019

# %%
df_19.rename(columns = {'area_title':'st'},inplace = True)

# %% [markdown]
# # merging everyone!

# %%
df = pd.concat([df_97,
                df_98,
                df_99,
                df_00,
                df_01,
                df_02,
                df_03,
                df_04,
                df_05,
                df_06,
                df_07,
                df_08,
                df_09,
                df_10,
                df_11,
                df_12,
                df_13,
                df_14,
                df_15,
                df_16,
                df_17,
                df_18,
                df_19
               ])

# %%
df.head()
# Out:
#     st occ_code                                          occ_title tot_emp  \
# 40  AL    10000          Managerial and Administrative Occupations     NaN
# 41  AL    13000  Staff and Administrative Specialty Managerial ...      **
# 42  AL    13002                                 Financial Managers    8140
# 43  AL    13005  Personnel, Training, and Labor Relations Managers    2760
# 44  AL    13008                                Purchasing Managers    2370
#
#    h_mean a_mean  year
# 40    NaN    NaN   NaN
# 41  18.04  37530  1997
# 42  24.23  50400  1997
# 43  20.84  43350  1997
# 44  19.07  39660  1997

# %%
df['year'].value_counts()
# Out:
# 2013    37725
# 2014    37717
# 2015    37642
# 2012    37634
# 2016    37561
# 2017    36992
# 2018    36897
# 2007    36822
# 2008    36765
# 2009    36728
# 2011    36637
# 2010    36566
# 2019    36382
# 2005    36240
# 2004    35859
# 2006    35797
# 1998    35322
# 1997    34055
# 2000    33192
# 2001    33000
# 2002    32406
# 2003    32355
# 1999    30447
# Name: year, dtype: int64

# %%
df.to_csv('../data/occupation_99_to_19.csv', index = False)
